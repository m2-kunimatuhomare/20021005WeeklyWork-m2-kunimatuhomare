# %%
2^2
# Out:
# 4

# %%
2^3
# Out:
# 8

# %%
2^4
# Out:
# 16

# %%
2 .^[2,3,4]
# Out:
# 3-element Vector{Int64}:
#   4
#   8
#  16

# %%
2.0.^[2,3,4]
# Out:
# 3-element Vector{Float64}:
#   4.0
#   8.0
#  16.0

# %%
[2,3,4] .^2
# Out:
# 3-element Vector{Int64}:
#   4
#   9
#  16

# %%
(2:4) .^2
# Out:
# 3-element Vector{Int64}:
#   4
#   9
#  16

# %%
2:4 .^2
# Out:
# 2:16

# %%
using PyPlot
plt.axes().set_aspect("equal")

xs = 0:0.1:1
plt.plot(xs, xs .^2)
plt.plot(xs, xs .^3)
plt.plot(xs, xs .^4)
plt.plot(xs, xs .^5)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 1-element Vector{PyCall.PyObject}:
#  PyObject <matplotlib.lines.Line2D object at 0x00000000016394E0>

# %%
xs = -3:0.5:3
# Out:
# -3.0:0.5:3.0

# %%
xs.^ 2 .+ 1
# Out:
# 13-element Vector{Float64}:
#  10.0
#   7.25
#   5.0
#   3.25
#   2.0
#   1.25
#   1.0
#   1.25
#   2.0
#   3.25
#   5.0
#   7.25
#  10.0

# %%
1 ./ (xs.^ 2 .+ 1)
# Out:
# 13-element Vector{Float64}:
#  0.1
#  0.13793103448275862
#  0.2
#  0.3076923076923077
#  0.5
#  0.8
#  1.0
#  0.8
#  0.5
#  0.3076923076923077
#  0.2
#  0.13793103448275862
#  0.1

# %%
using PyPlot

xs = -3:0.1:3
ys = 1 ./ (xs.^ 2 .+ 1)
plt.plot(xs, ys)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 1-element Vector{PyCall.PyObject}:
#  PyObject <matplotlib.lines.Line2D object at 0x00000000016B4CD0>

# %%
using PyPlot

xs = -3:0.05:3
gamma = 0.5
ys = (gamma / 2) ./ (xs.^ 2 .+ (gamma / 2)^2)
plt.plot(xs, ys, label = gamma)
gamma = 1.0
ys = (gamma / 2) ./ (xs.^ 2 .+ (gamma / 2)^2)
plt.plot(xs, ys, label = gamma)
gamma = 2.0
ys = (gamma / 2) ./ (xs.^ 2 .+ (gamma / 2)^2)
plt.plot(xs, ys, label = gamma)
plt.legend()
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.legend.Legend object at 0x0000000001707F40>

# %%
using PyPlot

xs = -3:0.05:3
for gamma in [0.5, 1.0, 2.0]
   local ys=(gamma / 2) ./ (xs.^ 2 .+ (gamma / 2)^2)
   plt.plot(xs, ys,
      label = gamma)
end
plt.legend()
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.legend.Legend object at 0x0000000000D75BA0>

# %%
using PyPlot

xs = -3:0.05:3
for gamma in [0.5, 1.0, 2.0]
   local ys=(gamma / 2) ./ (xs.^ 2 .+ (gamma / 2)^2) / (2 / gamma)
   plt.plot(xs,ys,
      label = gamma,
   )
end
plt.legend()
plt.axhline(1 / 2, color = "k", lw = 0.5)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.lines.Line2D object at 0x0000000001946080>

# %%
(2:2:4) * 2
# Out:
# 4:4:8

# %%
(2:2:4) / 2
# Out:
# 1.0:1.0:2.0

# %%
2:2:4 .+ 2
# Out:
# 2:2:6

# %%
2:2:4 .- 2
# Out:
# 2:2:2

# %%
xs = [1, 2, 2, 1]
# Out:
# 4-element Vector{Int64}:
#  1
#  2
#  2
#  1

# %%
ys = [1, 1, 3, 1]
# Out:
# 4-element Vector{Int64}:
#  1
#  1
#  3
#  1

# %%
xs .+ ys
# Out:
# 4-element Vector{Int64}:
#  2
#  3
#  5
#  2

# %%
xs .- ys
# Out:
# 4-element Vector{Int64}:
#   0
#   1
#  -1
#   0

# %%
xs = 100:100:300
# Out:
# 100:100:300

# %%
ys = 1:2:5
# Out:
# 1:2:5

# %%
xs .+ ys
# Out:
# 101:102:305

# %%
xs .- ys
# Out:
# 99:98:295

# %%
xs = 100:100:300
# Out:
# 100:100:300

# %%
ys = [1,3,5]
# Out:
# 3-element Vector{Int64}:
#  1
#  3
#  5

# %%
xs .+ ys
# Out:
# 3-element Vector{Int64}:
#  101
#  203
#  305

# %%
xs .- ys
# Out:
# 3-element Vector{Int64}:
#   99
#  197
#  295

# %%
xs = [1, 2, 4, 3]
# Out:
# 4-element Vector{Int64}:
#  1
#  2
#  4
#  3

# %%
ys = [2, 1, 2, 1]
# Out:
# 4-element Vector{Int64}:
#  2
#  1
#  2
#  1

# %%
xs .* ys
# Out:
# 4-element Vector{Int64}:
#  2
#  2
#  8
#  3

# %%
xs ./ ys
# Out:
# 4-element Vector{Float64}:
#  0.5
#  2.0
#  2.0
#  3.0

# %%
x = 1
# Out:
# 1

# %%
 x = x + 1
# Out:
# 2

# %%
x += 1
# Out:
# 3

# %%
gamma = 2
# Out:
# 2

# %%
for i = 1:5
          global gamma
          gamma /= 2
          @show gamma
       end
# Out:
# gamma = 1.0
# gamma = 0.5
# gamma = 0.25
# gamma = 0.125
# gamma = 0.0625

# %%
using PyPlot
xs = -3:0.05:3
gamma = 2
for i = 1:5
   global gamma
   local ys=(gamma / 2) ./ (xs.^ 2 .+ (gamma / 2)^2) / (2 / gamma)
   plt.plot(
      xs,ys,
      label = gamma,
   )
   gamma /= 2
end
plt.legend()
axhline(1 / 2, color = "k", lw = 0.5)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.lines.Line2D object at 0x00000000019B65F0>

# %%
xs = [1, 2, 2, 1]
# Out:
# 4-element Vector{Int64}:
#  1
#  2
#  2
#  1

# %%
xs *= 2
# Out:
# 4-element Vector{Int64}:
#  2
#  4
#  4
#  2

# %%
xs
# Out:
# 4-element Vector{Int64}:
#  2
#  4
#  4
#  2

# %%
using PyPlot
plt.axes().set_aspect("equal")

xs = [1.0, 2.0, 2.0, 1.0]
ys = [1.0, 1.0, 3.0, 1.0]
for i = 1:5
   global xs, ys
   plt.plot(xs, ys)
   xs *= 1.2
   ys *= 1.2
end
plt.xlim(0, 7)
plt.ylim(0, 7)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# (0.0, 7.0)

# %%
xs = [1, 2, 2, 1]
# Out:
# 4-element Vector{Int64}:
#  1
#  2
#  2
#  1

# %%
xs .+= 1
# Out:
# 4-element Vector{Int64}:
#  2
#  3
#  3
#  2

# %%
xs
# Out:
# 4-element Vector{Int64}:
#  2
#  3
#  3
#  2

# %%
using PyPlot
plt.axes().set_aspect("equal")

xs = [1.0, 2.0, 2.0, 1.0]
ys = [1.0, 1.0, 3.0, 1.0]
for i = 1:5
   global xs, ys
   plt.plot(xs, ys)
   xs .+= 0.5
   ys .+= 0.5
end
plt.xlim(0, 6)
plt.ylim(0, 6)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# (0.0, 6.0)

# %%
xs = [1, 2, 2, 1]
# Out:
# 4-element Vector{Int64}:
#  1
#  2
#  2
#  1

# %%
ys = [1, 1, 3, 1]
# Out:
# 4-element Vector{Int64}:
#  1
#  1
#  3
#  1

# %%
xs .+= ys
# Out:
# 4-element Vector{Int64}:
#  2
#  3
#  5
#  2

# %%
xs
# Out:
# 4-element Vector{Int64}:
#  2
#  3
#  5
#  2

# %%
xs .-= ys
# Out:
# 4-element Vector{Int64}:
#  1
#  2
#  2
#  1

# %%
xs
# Out:
# 4-element Vector{Int64}:
#  1
#  2
#  2
#  1
