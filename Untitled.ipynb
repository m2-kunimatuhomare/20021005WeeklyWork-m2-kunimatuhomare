# %%
2^2
# Out:
# 4

# %%
2^3
# Out:
# 8

# %%
2^4
# Out:
# 16

# %%
2 .^[2,3,4]
# Out:
# 3-element Vector{Int64}:
#   4
#   8
#  16

# %%
2.0.^[2,3,4]
# Out:
# 3-element Vector{Float64}:
#   4.0
#   8.0
#  16.0

# %%
[2,3,4] .^2
# Out:
# 3-element Vector{Int64}:
#   4
#   9
#  16

# %%
(2:4) .^2
# Out:
# 3-element Vector{Int64}:
#   4
#   9
#  16

# %%
2:4 .^2
# Out:
# 2:16

# %%
using PyPlot
plt.axes().set_aspect("equal")

xs = 0:0.1:1
plt.plot(xs, xs .^2)
plt.plot(xs, xs .^3)
plt.plot(xs, xs .^4)
plt.plot(xs, xs .^5)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 1-element Vector{PyCall.PyObject}:
#  PyObject <matplotlib.lines.Line2D object at 0x00000000016394E0>
